# %%
import pandas as pd
import numpy as np

file_name = "2020_al_data_kaggle_upload_new_old_syllabi.csv"

print("=" * 60)
print("1. LOADING AND CLEANING DATASET")
print("=" * 60)

# Load data treating '-' and spaces as NaN
df = pd.read_csv(file_name, na_values=["-", "", " ", "Absent"])

# Convert Zscore to numeric
if "Zscore" in df.columns:
    df["Zscore"] = pd.to_numeric(df["Zscore"], errors="coerce")

# Extract numeric values from rank strings (e.g. '4336 (NEW)' -> 4336)
for rank_col in ["district_rank", "island_rank"]:
    if rank_col in df.columns:
        df[f"{rank_col}_num"] = (
            df[rank_col]
            .astype(str)
            .str.extract(r"(\d+)")
            .astype(float)
        )

print(f"Total Records (Rows): {df.shape[0]:,}")
print(f"Total Columns:        {df.shape[1]}")
print(f"Duplicate Rows:       {df.duplicated().sum():,}")

print("\n" + "=" * 60)
print("2. COLUMN HEALTH & MISSING VALUES")
print("=" * 60)
overview = pd.DataFrame({
    "Data Type": df.dtypes,
    "Missing Count": df.isnull().sum(),
    "Missing (%)": (df.isnull().mean() * 100).round(2),
    "Unique Values": df.nunique()
})
print(overview.to_string())

print("\n" + "=" * 60)
print("3. NUMERIC SUMMARY STATISTICS")
print("=" * 60)
numeric_summary = df.describe().T
print(numeric_summary.to_string())

print("\n" + "=" * 60)
print("4. CATEGORICAL DISTRIBUTIONS (TOP 5 VALUES PER COLUMN)")
print("=" * 60)
categorical_cols = df.select_dtypes(include=["object", "category"]).columns

for col in categorical_cols:
    print(f"\n--- Distribution: {col} ---")
    val_counts = df[col].value_counts(dropna=False).head(5)
    percentages = (df[col].value_counts(normalize=True, dropna=False) * 100).round(2).head(5)
    dist_df = pd.DataFrame({"Count": val_counts, "Percentage (%)": percentages})
    print(dist_df.to_string())

# Export summary to CSV files for easy review
overview.to_csv("profile_column_health.csv")
numeric_summary.to_csv("profile_numeric_summary.csv")
print("\n[Done] Summary tables exported to 'profile_column_health.csv' and 'profile_numeric_summary.csv'.")
# Out:
# ============================================================
# 1. LOADING AND CLEANING DATASET
# ============================================================
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7244\1321407183.py:11: DtypeWarning: Columns (0: cgt_r) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name, na_values=["-", "", " ", "Absent"])
# Total Records (Rows): 337,553
# Total Columns:        21
# Duplicate Rows:       0
#
# ============================================================
# 2. COLUMN HEALTH & MISSING VALUES
# ============================================================
#                   Data Type  Missing Count  Missing (%)  Unique Values
# index                 int64              0         0.00         337553
# stream                  str         150514        44.59              7
# Zscore              float64         105249        31.18          33890
# district_rank           str         153254        45.40           8059
# island_rank             str         153254        45.40          47615
# al_year               int64              0         0.00              1
# sub1                    str              0         0.00             51
# sub1_r                  str          43581        12.91              6
# sub2                    str              0         0.00             60
# sub2_r                  str          45556        13.50              6
# sub3                    str              0         0.00             60
# sub3_r                  str          43332        12.84              7
# cgt_r                object          76628        22.70            116
# ge_r                    str          66140        19.59              6
# syllabus                str              0         0.00              2
# birth_day               str              0         0.00             34
# birth_month             str              0         0.00             15
# birth_year              str              0         0.00             76
# gender                  str           1484         0.44              3
# district_rank_num   float64         153254        45.40           7501
# island_rank_num     float64         153254        45.40          42071
#
# ============================================================
# 3. NUMERIC SUMMARY STATISTICS
# ============================================================
#                       count           mean           std        min         25%          50%          75%          max
# index              337553.0  168776.000000  97443.302045     0.0000  84388.0000  168776.0000  253164.0000  337552.0000
# Zscore             232304.0       0.305389      0.763854    -1.9383     -0.3002       0.2217       0.8528       3.5583
# al_year            337553.0    2020.000000      0.000000  2020.0000   2020.0000    2020.0000    2020.0000    2020.0000
# district_rank_num  184299.0    1304.358743   1423.551699     1.0000    269.0000     783.0000    1859.0000    7546.0000
# island_rank_num    184299.0   21584.624876  19429.420980     1.0000   5800.0000   15425.0000   33040.0000   73006.0000
#
# ============================================================
# 4. CATEGORICAL DISTRIBUTIONS (TOP 5 VALUES PER COLUMN)
# ============================================================
#
# --- Distribution: stream ---
#                      Count  Percentage (%)
# stream
# NaN                 150514           44.59
# ARTS                 76547           22.68
# COMMERCE             39877           11.81
# BIOLOGICAL SCIENCE   25768            7.63
# PHYSICAL SCIENCE     21776            6.45
#
# --- Distribution: district_rank ---
#                 Count  Percentage (%)
# district_rank
# NaN            153254           45.40
# 11 (NEW)          152            0.05
# 9 (NEW)           151            0.04
# 3 (NEW)           150            0.04
# 1 (NEW)           150            0.04
#
# --- Distribution: island_rank ---
# C:\Users\MSI\AppData\Local\Temp\ipykernel_7244\1321407183.py:51: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include=["object", "category"]).columns
#               Count  Percentage (%)
# island_rank
# NaN          153254           45.40
# 15404 (NEW)      21            0.01
# 10175 (NEW)      19            0.01
# 10890 (NEW)      19            0.01
# 14637 (NEW)      17            0.01
#
# --- Distribution: sub1 ---
#                                         Count  Percentage (%)
# sub1
# PHYSICS                                 88758           26.29
# ECONOMICS                               66538           19.71
# GEOGRAPHY                               52478           15.55
# POLITICAL SCIENCE                       36859           10.92
# INFORMATION & COMMUNICATION TECHNOLOGY  35337           10.47
#
# --- Distribution: sub1_r ---
#         Count  Percentage (%)
# sub1_r
# S       97338           28.84
# F       79006           23.41
# C       71764           21.26
# NaN     43581           12.91
# B       27111            8.03
#
# --- Distribution: sub2 ---
#                         Count  Percentage (%)
# sub2
# CHEMISTRY               83993           24.88
# BUSINESS STUDIES        62466           18.51
# BUDDHIST CIVILIZATION   27395            8.12
# ENGINEERING TECHNOLOGY  24388            7.22
# POLITICAL SCIENCE       18830            5.58
#
# --- Distribution: sub2_r ---
#         Count  Percentage (%)
# sub2_r
# S       89408           26.49
# C       80261           23.78
# F       59559           17.64
# NaN     45556           13.50
# B       37328           11.06
#
# --- Distribution: sub3 ---
#                         Count  Percentage (%)
# sub3
# SINHALA                 75708           22.43
# ACCOUNTING              64900           19.23
# BIOLOGY                 50723           15.03
# COMBINED MATHEMATICS    39094           11.58
# SCIENCE FOR TECHNOLOGY  37869           11.22
#
# --- Distribution: sub3_r ---
#         Count  Percentage (%)
# sub3_r
# S       88383           26.18
# C       75781           22.45
# F       55258           16.37
# B       46710           13.84
# NaN     43332           12.84
#
# --- Distribution: cgt_r ---
#        Count  Percentage (%)
# cgt_r
# NaN    76628           22.70
# 040    12647            3.75
# 042    12475            3.70
# 038    12080            3.58
# 044    11782            3.49
#
# --- Distribution: ge_r ---
#        Count  Percentage (%)
# ge_r
# F     123804           36.68
# S      69820           20.68
# NaN    66140           19.59
# C      36080           10.69
# A      23093            6.84
#
# --- Distribution: syllabus ---
#            Count  Percentage (%)
# syllabus
# new       306211           90.71
# old        31342            9.29
#
# --- Distribution: birth_day ---
#            Count  Percentage (%)
# birth_day
# 1          11297            3.35
# 10         11296            3.35
# 21         11265            3.34
# 20         11199            3.32
# 23         11188            3.31
#
# --- Distribution: birth_month ---
#              Count  Percentage (%)
# birth_month
# May          29424            8.72
# October      29350            8.69
# March        29203            8.65
# April        28714            8.51
# January      28616            8.48
#
# --- Distribution: birth_year ---
#              Count  Percentage (%)
# birth_year
# 2001        185402           54.93
# 2000         90735           26.88
# 1999         24155            7.16
# 2002         16236            4.81
# 1998          6561            1.94
#
# --- Distribution: gender ---
#               Count  Percentage (%)
# gender
# female       193326           57.27
# male         142719           42.28
# NaN            1484            0.44
# Major error      24            0.01
#
# [Done] Summary tables exported to 'profile_column_health.csv' and 'profile_numeric_summary.csv'.

# %%
pip install pandas numpy
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.5.2-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp314-cp314-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 984.8 kB/s eta 0:00:10
#    --- ------------------------------------ 0.8/10.0 MB 976.8 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.3/10.0 MB 1.3 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/10.0 MB 1.4 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/10.0 MB 1.4 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/10.0 MB 1.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.9/10.0 MB 1.6 MB/s eta 0:00:05
#    ------------ --------------------------- 3.1/10.0 MB 1.7 MB/s eta 0:00:05
#    --------------- ------------------------ 3.9/10.0 MB 1.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.5/10.0 MB 1.9 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/10.0 MB 1.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.5/10.0 MB 2.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.8/10.0 MB 2.0 MB/s eta 0:00:03
#    ------------------------- -------------- 6.3/10.0 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/10.0 MB 2.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.3/10.0 MB 2.0 MB/s eta 0:00:02
#    ------------------------------- -------- 7.9/10.0 MB 2.0 MB/s eta 0:00:02
#    --------------------------------- ------ 8.4/10.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/10.0 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.0 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 2.1 MB/s  0:00:05
# Downloading numpy-2.5.2-cp314-cp314-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 3.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/12.6 MB 3.1 MB/s eta 0:00:04
#    ------ --------------------------------- 2.1/12.6 MB 2.7 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.6 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 3.1/12.6 MB 2.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.4/12.6 MB 2.5 MB/s eta 0:00:04
#    ------------ --------------------------- 3.9/12.6 MB 2.5 MB/s eta 0:00:04
#    -------------- ------------------------- 4.7/12.6 MB 2.5 MB/s eta 0:00:04
#    --------------- ------------------------ 5.0/12.6 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 5.2/12.6 MB 2.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.5/12.6 MB 2.3 MB/s eta 0:00:04
#    ------------------ --------------------- 5.8/12.6 MB 2.1 MB/s eta 0:00:04
#    ------------------- -------------------- 6.3/12.6 MB 2.2 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.6 MB 2.3 MB/s eta 0:00:03
#    ------------------------ --------------- 7.6/12.6 MB 2.3 MB/s eta 0:00:03
#    -------------------------- ------------- 8.4/12.6 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.6 MB 2.5 MB/s eta 0:00:02
#    ------------------------------ --------- 9.7/12.6 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.2/12.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.6 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 2.6 MB/s  0:00:04
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, numpy, pandas
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed numpy-2.5.2 pandas-3.0.5 tzdata-2026.3
# Note: you may need to restart the kernel to use updated packages.
